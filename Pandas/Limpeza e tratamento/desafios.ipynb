# %% [markdown]
# # Aula 1

# %%
import json
import pandas as pd

# %%
with open('informacoes.json', encoding='UTF-8') as f:
    dados = json.load(f)

# %%
dados
# Out:
# {'nome': 'João',
#  'idade': 28,
#  'enderecos': [{'tipo': 'casa',
#    'rua': 'Rua A',
#    'numero': 123,
#    'cidade': 'São Paulo'},
#   {'tipo': 'trabalho',
#    'rua': 'Rua B',
#    'numero': 456,
#    'cidade': 'Rio de Janeiro'}]}

# %%
pd.json_normalize(dados, record_path='enderecos', meta=['nome', 'idade'])
# Out:
#        tipo    rua  numero          cidade  nome idade
# 0      casa  Rua A     123       São Paulo  João    28
# 1  trabalho  Rua B     456  Rio de Janeiro  João    28

# %% [markdown]
# # Aula 2
# Sua tarefa é realizar alguns tratamentos e deixar esse arquivo JSON como um Pandas DataFrame, sem dados vazios e com a tipagem das colunas de forma correta.

# %%
with open('dados.json', encoding='UTF-8') as f:
    dados = json.load(f)

# %%
dados = pd.json_normalize(dados, 'pessoas', errors='ignore')
dados
# Out:
#     nome idade                     telefones endereco.rua  endereco.numero  \
# 0   João    25  [11 1111-1111, 11 2222-2222]        Rua A              123
# 1  Maria    30                [21 3333-3333]                           456
#
#   endereco.cidade
# 0       São Paulo
# 1  Rio de Janeiro

# %%
dados['idade'] = dados['idade'].astype(int)
dados
# Out:
#     nome  idade                     telefones endereco.rua  endereco.numero  \
# 0   João     25  [11 1111-1111, 11 2222-2222]        Rua A              123
# 1  Maria     30                [21 3333-3333]                           456
#
#   endereco.cidade
# 0       São Paulo
# 1  Rio de Janeiro

# %%
dados = dados[dados['endereco.rua'] != '']
dados
# Out:
#    nome  idade                     telefones endereco.rua  endereco.numero  \
# 0  João     25  [11 1111-1111, 11 2222-2222]        Rua A              123
#
#   endereco.cidade
# 0       São Paulo

# %% [markdown]
# # Aula 3
# Remover valores nulos, duplicatas e strings vazias. Converter tipos das colunas.

# %%
with open('cursos_cadastrados.json', encoding='UTF-8') as f:
    cursos = json.load(f)

# %%
cursos = pd.json_normalize(cursos)
cursos
# Out:
#                              curso      categoria carga_horaria concluintes  \
# 0         Introdução à programação    Programação      20 horas         100
# 1            Excel para iniciantes  Produtividade          None        None
# 2  Marketing digital para negócios      Marketing      30 horas          75
# 3          Inteligência artificial    Programação      40 horas
# 4             Inglês para negócios        Idiomas      20 horas          30
# 5         Introdução à programação    Programação      20 horas         100
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 1        None           None
# 2  2022-03-01     2022-03-31
# 3  2022-04-01
# 4
# 5  2022-01-01     2022-01-20
#
#                                            descricao  preco  instrutor.nome  \
# 0        Curso introdutório à programação com Python  99.90      João Silva
# 1                                               None   None  Maria Oliveira
# ...

# %%
cursos.isna()
# Out:
#    curso  categoria  carga_horaria  concluintes  data_inicio  data_conclusao  \
# 0  False      False          False        False        False           False
# 1  False      False           True         True         True            True
# 2  False      False          False        False        False           False
# 3  False      False          False        False        False           False
# 4  False      False          False        False        False           False
# 5  False      False          False        False        False           False
#
#    descricao  preco  instrutor.nome  instrutor.email  instrutor.telefone
# 0      False  False           False            False               False
# 1       True   True           False            False               False
# 2      False  False           False            False               False
# 3      False  False           False            False               False
# ...

# %%
cursos[cursos.isna().any(axis=1)]
# Out:
#                    curso      categoria carga_horaria concluintes data_inicio  \
# 1  Excel para iniciantes  Produtividade          None        None        None
#
#   data_conclusao descricao preco  instrutor.nome  \
# 1           None      None  None  Maria Oliveira
#
#                      instrutor.email instrutor.telefone
# 1  maria.oliveira@emailaleatorio.com     (11) 8888-8888

# %%
cursos.dropna(inplace=True)
cursos
# Out:
#                              curso    categoria carga_horaria concluintes  \
# 0         Introdução à programação  Programação      20 horas         100
# 2  Marketing digital para negócios    Marketing      30 horas          75
# 3          Inteligência artificial  Programação      40 horas
# 4             Inglês para negócios      Idiomas      20 horas          30
# 5         Introdução à programação  Programação      20 horas         100
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 2  2022-03-01     2022-03-31
# 3  2022-04-01
# 4
# 5  2022-01-01     2022-01-20
#
#                                            descricao  preco instrutor.nome  \
# 0        Curso introdutório à programação com Python  99.90     João Silva
# 2                    Curso introdutório em marketing   89.9     Ana Santos
# 3  Curso avançado sobre inteligência artificial c...  129.9
# 4                      Curso de inglês para negócios   69.9     John Smith
# ...

# %%
cursos[cursos.duplicated()]
# Out:
#                       curso    categoria carga_horaria concluintes  \
# 5  Introdução à programação  Programação      20 horas         100
#
#   data_inicio data_conclusao                                    descricao  \
# 5  2022-01-01     2022-01-20  Curso introdutório à programação com Python
#
#    preco instrutor.nome                instrutor.email instrutor.telefone
# 5  99.90     João Silva  joao.silva@emailaleatorio.com     (11) 9999-9999

# %%
cursos.drop_duplicates(inplace=True)
cursos
# Out:
#                              curso    categoria carga_horaria concluintes  \
# 0         Introdução à programação  Programação      20 horas         100
# 2  Marketing digital para negócios    Marketing      30 horas          75
# 3          Inteligência artificial  Programação      40 horas
# 4             Inglês para negócios      Idiomas      20 horas          30
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 2  2022-03-01     2022-03-31
# 3  2022-04-01
# 4
#
#                                            descricao  preco instrutor.nome  \
# 0        Curso introdutório à programação com Python  99.90     João Silva
# 2                    Curso introdutório em marketing   89.9     Ana Santos
# 3  Curso avançado sobre inteligência artificial c...  129.9
# 4                      Curso de inglês para negócios   69.9     John Smith
#
#                  instrutor.email instrutor.telefone
# 0  joao.silva@emailaleatorio.com     (11) 9999-9999
# ...

# %%
cursos[cursos['instrutor.nome'] == '']
# Out:
#                      curso    categoria carga_horaria concluintes data_inicio  \
# 3  Inteligência artificial  Programação      40 horas              2022-04-01
#
#   data_conclusao                                          descricao  preco  \
# 3                 Curso avançado sobre inteligência artificial c...  129.9
#
#   instrutor.nome             instrutor.email instrutor.telefone
# 3                 contato@emailaleatorio.com

# %%
cursos = cursos[cursos['instrutor.nome'] != '']
cursos
# Out:
#                              curso    categoria carga_horaria concluintes  \
# 0         Introdução à programação  Programação      20 horas         100
# 2  Marketing digital para negócios    Marketing      30 horas          75
# 4             Inglês para negócios      Idiomas      20 horas          30
#
#   data_inicio data_conclusao                                    descricao  \
# 0  2022-01-01     2022-01-20  Curso introdutório à programação com Python
# 2  2022-03-01     2022-03-31              Curso introdutório em marketing
# 4                                           Curso de inglês para negócios
#
#    preco instrutor.nome                instrutor.email instrutor.telefone
# 0  99.90     João Silva  joao.silva@emailaleatorio.com     (11) 9999-9999
# 2   89.9     Ana Santos  ana.santos@emailaleatorio.com     (11) 7777-7777
# 4   69.9     John Smith

# %%
cursos.replace('', pd.NA, inplace=True)
cursos
# Out:
# C:\Users\thiag\AppData\Local\Temp\ipykernel_28600\2911958659.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   cursos.replace('', pd.NA, inplace=True)
# C:\Users\thiag\AppData\Local\Temp\ipykernel_28600\2911958659.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cursos.replace('', pd.NA, inplace=True)
#                              curso    categoria carga_horaria  concluintes  \
# 0         Introdução à programação  Programação      20 horas          100
# 2  Marketing digital para negócios    Marketing      30 horas           75
# ...

# %%
cursos.dropna(inplace=True)
cursos
# Out:
# C:\Users\thiag\AppData\Local\Temp\ipykernel_28600\1630479215.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cursos.dropna(inplace=True)
#                              curso    categoria carga_horaria  concluintes  \
# 0         Introdução à programação  Programação      20 horas          100
# 2  Marketing digital para negócios    Marketing      30 horas           75
#
#   data_inicio data_conclusao                                    descricao  \
# 0  2022-01-01     2022-01-20  Curso introdutório à programação com Python
# 2  2022-03-01     2022-03-31              Curso introdutório em marketing
#
#    preco instrutor.nome                instrutor.email instrutor.telefone
# 0  99.90     João Silva  joao.silva@emailaleatorio.com     (11) 9999-9999
# ...

# %%
cursos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 0 to 2
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   curso               2 non-null      object
#  1   categoria           2 non-null      object
#  2   carga_horaria       2 non-null      object
#  3   concluintes         2 non-null      int64
#  4   data_inicio         2 non-null      object
#  5   data_conclusao      2 non-null      object
#  6   descricao           2 non-null      object
#  7   preco               2 non-null      object
#  8   instrutor.nome      2 non-null      object
#  9   instrutor.email     2 non-null      object
#  10  instrutor.telefone  2 non-null      object
# dtypes: int64(1), object(10)
# memory usage: 192.0+ bytes

# %%
colunas_to_date = ['data_inicio', 'data_conclusao']
colunas_to_float = ['preco']

# %%
cursos[colunas_to_date]
# Out:
#   data_inicio data_conclusao
# 0  2022-01-01     2022-01-20
# 2  2022-03-01     2022-03-31

# %%
import numpy as np

pd.to_datetime(cursos['data_inicio'])
pd.to_datetime(cursos['data_conclusao'])
# Out:
# 0   2022-01-20
# 2   2022-03-31
# Name: data_conclusao, dtype: datetime64[ns]

# %%
cursos['preco'] = cursos['preco'].astype(np.float64)
cursos
# Out:
# C:\Users\thiag\AppData\Local\Temp\ipykernel_28600\713416390.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cursos['preco'] = cursos['preco'].astype(np.float64)
#                              curso    categoria carga_horaria  concluintes  \
# 0         Introdução à programação  Programação      20 horas          100
# 2  Marketing digital para negócios    Marketing      30 horas           75
#
#   data_inicio data_conclusao                                    descricao  \
# 0  2022-01-01     2022-01-20  Curso introdutório à programação com Python
# 2  2022-03-01     2022-03-31              Curso introdutório em marketing
#
#    preco instrutor.nome                instrutor.email instrutor.telefone
# ...

# %% [markdown]
# # Aula 4
# Sua missão é construir uma função que recebe dois parâmetros, a coluna que você quer analisar se tem outlier e o DataFrame em questão.

# %%
import pandas as pd

# criando um DataFrame com 30 transações aleatórias
df = pd.DataFrame({
    'ID da transação': range(1, 31),
    'Valor da transação': [100, 200, 150, 500, 300, 913, 250, 400, 200, 150, 
                           200, 200, 400, 300, 150, 301, 805, 300, 400, 250, 
                           150, 100, 500, 600, 200, 350, 100, 250, 800, 250],
    'Data da transação': pd.date_range(start='2022-01-01', end='2022-01-30', freq='D'),
    'Local da transação': ['São Paulo, Brasil', 'Rio de Janeiro, Brasil', 'Belo Horizonte, Brasil', 'São Paulo, Brasil', 
                           'São Paulo, Brasil', 'Nova Iorque, EUA', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil',
                           'Rio de Janeiro, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil',
                           'São Paulo, Brasil', 'São Paulo, Brasil', 'Los Angeles, EUA', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil',
                           'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil',
                           'São Paulo, Brasil', 'São Paulo, Brasil', 'Miami, EUA', 'São Paulo, Brasil']
})

# %%
def identificar_outliers(coluna_: str, data_frame_: pd.DataFrame):
    series_para_busca = data_frame_[coluna_]
    Q1 = series_para_busca.quantile(0.25)
    Q2 = series_para_busca.quantile(0.75)
    IQR = Q2 - Q1
    limite_inferior = Q1 - 1.5 * IQR
    limite_superior = Q2 + 1.5 * IQR

    index_outliers = (series_para_busca < limite_inferior) | (series_para_busca > limite_superior)
    return data_frame_.loc[index_outliers, coluna_]

# %%
outliers = identificar_outliers('Valor da transação', df)
outliers
# Out:
# 5     913
# 16    805
# 28    800
# Name: Valor da transação, dtype: int64
